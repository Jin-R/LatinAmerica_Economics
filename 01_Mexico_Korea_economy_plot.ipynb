# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
print(plt.rcParams['font.family'])
# Out:
# ['Malgun Gothic']

# %% [markdown]
# # GDP(명목)

# %%
gdp = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/gdp.csv', thousands=',')
gdp.head(5)
# Out:
#    year       Korea       Mexico
# 0  1960  3957240261  13040000000
# 1  1961  2417638423  14160000000
# 2  1962  2813856976  15200000000
# 3  1963  3988476879  16960000000
# 4  1964  3458565257  20080000000

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    59 non-null     int64
#  1   Korea   59 non-null     int64
#  2   Mexico  59 non-null     int64
# dtypes: int64(3)
# memory usage: 1.5 KB

# %%
plt.plot(gdp.year, gdp.Korea, color='r')
plt.plot(gdp.year, gdp.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('GDP(명목)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./GDP(명목).jpg', dpi=100)

# %% [markdown]
# # GDP(%)

# %%
plt.rcParams['font.family'] = 'NanumGothic'
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
gdp_growth = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/gdp_growth.csv', thousands=',')
gdp_growth.head(5)
# Out:
#    year  Korea  Mexico
# 0  1961    6.9     5.0
# 1  1962    3.8     4.7
# 2  1963    9.2     8.1
# 3  1964    9.5    11.9
# 4  1965    7.2     7.1

# %%
gdp_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    58 non-null     int64
#  1   Korea   58 non-null     float64
#  2   Mexico  58 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.5 KB

# %%
plt.plot(gdp_growth.year, gdp_growth.Korea, color='r')
plt.plot(gdp_growth.year, gdp_growth.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('GDP(%)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./GDP(상승률, %).jpg', dpi=100)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # GDP(PPP)

# %%
gdp_ppp = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/gdp_ppp.csv', thousands=',')
gdp_ppp.head(5)
# Out:
#    year         Korea        Mexico
# 0  1990  354674985103  545539459080
# 1  1991  404633979976  588613053434
# 2  1992  439412870062  625706437347
# 3  1993  480622075989  758247409112
# 4  1994  536076762055  812704221638

# %%
gdp_ppp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    29 non-null     int64
#  1   Korea   29 non-null     int64
#  2   Mexico  29 non-null     int64
# dtypes: int64(3)
# memory usage: 824.0 bytes

# %%
plt.plot(gdp_ppp.year, gdp_ppp.Korea, color='r')
plt.plot(gdp_ppp.year, gdp_ppp.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('GDP(PPP)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./GDP(PPP).jpg', dpi=100)

# %% [markdown]
# # GNI (atlas)

# %%
gni_atlas = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/gni_atlas.csv', thousands=',')
gni_atlas.head(5)
# Out:
#    year  Korea  Mexico
# 0  1962    120     360
# 1  1963    120     390
# 2  1964    130     440
# 3  1965    130     480
# 4  1966    140     510

# %%
gni_atlas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    57 non-null     int64
#  1   Korea   57 non-null     int64
#  2   Mexico  57 non-null     int64
# dtypes: int64(3)
# memory usage: 1.5 KB

# %%
plt.plot(gni_atlas.year, gni_atlas.Korea, color='r')
plt.plot(gni_atlas.year, gni_atlas.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('GNI(Atlas)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./GNI(Atlas).jpg', dpi=100)

# %% [markdown]
# # GNI(PPP)

# %%
gni_ppp = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/gni_ppp.csv', thousands=',')
gni_ppp.head(5)
# Out:
#    year  Korea  Mexico
# 0  1990   8260    6280
# 1  1991   9330    6690
# 2  1992  10020    7000
# 3  1993  10850    8360
# 4  1994  11970    8800

# %%
gni_ppp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    29 non-null     int64
#  1   Korea   29 non-null     int64
#  2   Mexico  29 non-null     int64
# dtypes: int64(3)
# memory usage: 824.0 bytes

# %%
plt.plot(gni_ppp.year, gni_ppp.Korea, color='r')
plt.plot(gni_ppp.year, gni_ppp.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('GNI(PPP)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./GNI(PPP).jpg', dpi=100)

# %% [markdown]
# # Saving

# %%
saving = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/saving.csv', thousands=',')
saving.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     float64
#  2   Mexico  40 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.1 KB

# %%
plt.plot(saving.year, saving.Korea, color='r')
plt.plot(saving.year, saving.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Saving')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./saving.jpg', dpi=100)

# %% [markdown]
# # Deposit_rate

# %%
deposit_rate = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/deposit_rate.csv', thousands=',')
deposit_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    24 non-null     int64
#  1   Korea   24 non-null     float64
#  2   Mexico  24 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 704.0 bytes

# %%
plt.plot(deposit_rate.year, deposit_rate.Korea, color='r')
plt.plot(deposit_rate.year, deposit_rate.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Deposit Rate')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./deposit_rate.jpg', dpi=100)

# %% [markdown]
# # loan_rate

# %%
loan_rate = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/loan_rate.csv', thousands=',')
loan_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    24 non-null     int64
#  1   Korea   24 non-null     float64
#  2   Mexico  24 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 704.0 bytes

# %%
plt.plot(loan_rate.year, loan_rate.Korea, color='r')
plt.plot(loan_rate.year, loan_rate.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Loan Rate')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./loan_rate.jpg', dpi=100)

# %% [markdown]
# # inflation

# %%
inflation = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/inflation.csv', thousands=',')
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    60 non-null     int64
#  1   Korea   60 non-null     float64
#  2   Mexico  60 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.5 KB

# %%
plt.plot(inflation.year, inflation.Korea, color='r')
plt.plot(inflation.year, inflation.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Inflation')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./inflation.jpg', dpi=100)

# %% [markdown]
# # current

# %%
current = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/curent.csv', thousands=',')
current.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     int64
#  2   Mexico  40 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(current.year, current.Korea, color='r')
plt.plot(current.year, current.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Current')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./current.jpg', dpi=100)

# %% [markdown]
# # current_gdp

# %%
current_gdp = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/curent_gdp.csv', thousands=',')
current_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     float64
#  2   Mexico  40 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.1 KB

# %%
plt.plot(current_gdp.year, current_gdp.Korea, color='r')
plt.plot(current_gdp.year, current_gdp.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Current (GDP)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./current_gdp.jpg', dpi=100)

# %% [markdown]
# # export_good

# %%
export_good = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/export_good.csv', thousands=',')
export_good.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     int64
#  2   Mexico  40 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(export_good.year, export_good.Korea, color='r')
plt.plot(export_good.year, export_good.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Export (Good)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./export_good.jpg', dpi=100)

# %% [markdown]
# # export_service

# %%
export_service = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/export_service.csv', thousands=',')
export_service.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     int64
#  2   Mexico  40 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(export_service.year, export_service.Korea, color='r')
plt.plot(export_service.year, export_service.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Export (Service)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./export_service.jpg', dpi=100)

# %% [markdown]
# # import_good

# %%
import_good = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/import_good.csv', thousands=',')
import_good.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     int64
#  2   Mexico  40 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(import_good.year, import_good.Korea, color='r')
plt.plot(import_good.year, import_good.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Import (Good)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./import_good.jpg', dpi=100)

# %% [markdown]
# # import_service

# %%
import_service = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/import_service.csv', thousands=',')
import_service.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43 non-null     int64
#  1   Korea   43 non-null     int64
#  2   Mexico  40 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(import_service.year, import_service.Korea, color='r')
plt.plot(import_service.year, import_service.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Import (Service)')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./import_service.jpg', dpi=100)

# %% [markdown]
# # unimployment

# %%
unimployment = pd.read_csv('C:/Users/1102j/anaconda/LA_Economics/unimployment.csv', thousands=',')
unimployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    29 non-null     int64
#  1   Korea   29 non-null     float64
#  2   Mexico  29 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 824.0 bytes

# %%
plt.plot(unimployment.year, unimployment.Korea, color='r')
plt.plot(unimployment.year, unimployment.Mexico, color='g')
plt.xlabel('year')
plt.ylabel('Unimployment')
plt.legend(['Korea', 'Mexico'], fontsize=12)
plt.savefig('./unimployment.jpg', dpi=100)
