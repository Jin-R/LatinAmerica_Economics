# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./data/Argentina_GDP.csv')
data
# Out:
#     DATE           GDP
# 0   1962  2.445060e+10
# 1   1963  1.827212e+10
# 2   1964  2.560525e+10
# 3   1965  2.834471e+10
# 4   1966  2.863047e+10
# 5   1967  2.425667e+10
# 6   1968  2.643686e+10
# 7   1969  3.125628e+10
# 8   1970  3.158421e+10
# 9   1971  3.329320e+10
# 10  1972  3.473300e+10
# 11  1973  5.254400e+10
# 12  1974  7.243678e+10
# 13  1975  5.243865e+10
# 14  1976  5.116950e+10
# 15  1977  5.678100e+10
# 16  1978  5.808287e+10
# 17  1979  6.925233e+10
# 18  1980  7.696192e+10
# 19  1981  7.867684e+10
# 20  1982  8.430749e+10
# 21  1983  1.039790e+11
# 22  1984  7.909200e+10
# 23  1985  8.841667e+10
# 24  1986  1.109340e+11
# 25  1987  1.111060e+11
# 26  1988  1.262070e+11
# 27  1989  7.663690e+10
# 28  1990  1.413520e+11
# 29  1991  1.897200e+11
# 30  1992  2.287890e+11
# 31  1993  2.367420e+11
# 32  1994  2.574400e+11
# 33  1995  2.580320e+11
# 34  1996  2.721500e+11
# 35  1997  2.928590e+11
# 36  1998  2.989480e+11
# 37  1999  2.835230e+11
# 38  2000  2.842040e+11
# 39  2001  2.686970e+11
# 40  2002  9.772400e+10
# 41  2003  1.275870e+11
# 42  2004  1.646580e+11
# 43  2005  1.987370e+11
# 44  2006  2.325570e+11
# 45  2007  2.875310e+11
# 46  2008  3.615580e+11
# 47  2009  3.329760e+11
# 48  2010  4.236270e+11
# 49  2011  5.301630e+11
# 50  2012  5.459820e+11
# 51  2013  5.520250e+11
# 52  2014  5.263200e+11
# 53  2015  5.947490e+11
# 54  2016  5.575310e+11
# 55  2017  6.436290e+11
# 56  2018  5.176270e+11
# 57  2019  4.454450e+11
# 58  2020  3.830670e+11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    59 non-null     int64
#  1   GDP     59 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.0 KB

# %%
data['DATE'] = pd.to_datetime(data['DATE'], format='%Y')
data
# Out:
#          DATE           GDP
# 0  1962-01-01  2.445060e+10
# 1  1963-01-01  1.827212e+10
# 2  1964-01-01  2.560525e+10
# 3  1965-01-01  2.834471e+10
# 4  1966-01-01  2.863047e+10
# 5  1967-01-01  2.425667e+10
# 6  1968-01-01  2.643686e+10
# 7  1969-01-01  3.125628e+10
# 8  1970-01-01  3.158421e+10
# 9  1971-01-01  3.329320e+10
# 10 1972-01-01  3.473300e+10
# 11 1973-01-01  5.254400e+10
# 12 1974-01-01  7.243678e+10
# 13 1975-01-01  5.243865e+10
# 14 1976-01-01  5.116950e+10
# 15 1977-01-01  5.678100e+10
# 16 1978-01-01  5.808287e+10
# 17 1979-01-01  6.925233e+10
# 18 1980-01-01  7.696192e+10
# 19 1981-01-01  7.867684e+10
# 20 1982-01-01  8.430749e+10
# 21 1983-01-01  1.039790e+11
# 22 1984-01-01  7.909200e+10
# 23 1985-01-01  8.841667e+10
# 24 1986-01-01  1.109340e+11
# 25 1987-01-01  1.111060e+11
# 26 1988-01-01  1.262070e+11
# 27 1989-01-01  7.663690e+10
# 28 1990-01-01  1.413520e+11
# 29 1991-01-01  1.897200e+11
# 30 1992-01-01  2.287890e+11
# 31 1993-01-01  2.367420e+11
# 32 1994-01-01  2.574400e+11
# 33 1995-01-01  2.580320e+11
# 34 1996-01-01  2.721500e+11
# 35 1997-01-01  2.928590e+11
# 36 1998-01-01  2.989480e+11
# 37 1999-01-01  2.835230e+11
# 38 2000-01-01  2.842040e+11
# 39 2001-01-01  2.686970e+11
# 40 2002-01-01  9.772400e+10
# 41 2003-01-01  1.275870e+11
# 42 2004-01-01  1.646580e+11
# 43 2005-01-01  1.987370e+11
# 44 2006-01-01  2.325570e+11
# 45 2007-01-01  2.875310e+11
# 46 2008-01-01  3.615580e+11
# 47 2009-01-01  3.329760e+11
# 48 2010-01-01  4.236270e+11
# 49 2011-01-01  5.301630e+11
# 50 2012-01-01  5.459820e+11
# 51 2013-01-01  5.520250e+11
# 52 2014-01-01  5.263200e+11
# 53 2015-01-01  5.947490e+11
# 54 2016-01-01  5.575310e+11
# 55 2017-01-01  6.436290e+11
# 56 2018-01-01  5.176270e+11
# 57 2019-01-01  4.454450e+11
# 58 2020-01-01  3.830670e+11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    59 non-null     datetime64[ns]
#  1   GDP     59 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.0 KB

# %%
data.index = data['DATE']
data.set_index('DATE', inplace=True)
data
# Out:
#                      GDP
# DATE
# 1962-01-01  2.445060e+10
# 1963-01-01  1.827212e+10
# 1964-01-01  2.560525e+10
# 1965-01-01  2.834471e+10
# 1966-01-01  2.863047e+10
# 1967-01-01  2.425667e+10
# 1968-01-01  2.643686e+10
# 1969-01-01  3.125628e+10
# 1970-01-01  3.158421e+10
# 1971-01-01  3.329320e+10
# 1972-01-01  3.473300e+10
# 1973-01-01  5.254400e+10
# 1974-01-01  7.243678e+10
# 1975-01-01  5.243865e+10
# 1976-01-01  5.116950e+10
# 1977-01-01  5.678100e+10
# 1978-01-01  5.808287e+10
# 1979-01-01  6.925233e+10
# 1980-01-01  7.696192e+10
# 1981-01-01  7.867684e+10
# 1982-01-01  8.430749e+10
# 1983-01-01  1.039790e+11
# 1984-01-01  7.909200e+10
# 1985-01-01  8.841667e+10
# 1986-01-01  1.109340e+11
# 1987-01-01  1.111060e+11
# 1988-01-01  1.262070e+11
# 1989-01-01  7.663690e+10
# 1990-01-01  1.413520e+11
# 1991-01-01  1.897200e+11
# 1992-01-01  2.287890e+11
# 1993-01-01  2.367420e+11
# 1994-01-01  2.574400e+11
# 1995-01-01  2.580320e+11
# 1996-01-01  2.721500e+11
# 1997-01-01  2.928590e+11
# 1998-01-01  2.989480e+11
# 1999-01-01  2.835230e+11
# 2000-01-01  2.842040e+11
# 2001-01-01  2.686970e+11
# 2002-01-01  9.772400e+10
# 2003-01-01  1.275870e+11
# 2004-01-01  1.646580e+11
# 2005-01-01  1.987370e+11
# 2006-01-01  2.325570e+11
# 2007-01-01  2.875310e+11
# 2008-01-01  3.615580e+11
# 2009-01-01  3.329760e+11
# 2010-01-01  4.236270e+11
# 2011-01-01  5.301630e+11
# 2012-01-01  5.459820e+11
# 2013-01-01  5.520250e+11
# 2014-01-01  5.263200e+11
# 2015-01-01  5.947490e+11
# 2016-01-01  5.575310e+11
# 2017-01-01  6.436290e+11
# 2018-01-01  5.176270e+11
# 2019-01-01  4.454450e+11
# 2020-01-01  3.830670e+11

# %%
data.plot()
#plt.show()
plt.savefig('./GDP.png')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(data)
plt.savefig('./GDP_diff0_acf.png')

plot_pacf(data)
plt.savefig('./GDP_diff0_pacf.png')
#plt.show()

# %%
# 1차 차분
data_1 = data.diff(periods=1).iloc[1:]
data_1.plot()
plt.savefig('./GDP_diff1.png')

plot_acf(data_1)
plt.savefig('./GDP_diff1_acf.png')
plot_pacf(data_1)
plt.savefig('./GDP_diff1_pacf.png')
#plt.show()

# %% [markdown]
# AR=0, 차분=1, MR=0

# %%
model = ARIMA(data, order=(2, 1, 2))
model_fit = model.fit(trend='c',full_output=True, disp=1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.GDP   No. Observations:                   58
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1501.055
# Method:                       css-mle   S.D. of innovations    40642943526.818
# Date:                Thu, 09 Dec 2021   AIC                           3014.109
# Time:                        08:15:31   BIC                           3026.472
# Sample:                    01-01-1963   HQIC                          3018.925
#                          - 01-01-2020
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        6.183e+09   6.35e+09      0.974      0.330   -6.26e+09    1.86e+10
# ar.L1.D.GDP    -1.0734      0.124     -8.678      0.000      -1.316      -0.831
# ar.L2.D.GDP    -0.6647      0.114     -5.852      0.000      -0.887      -0.442
# ma.L1.D.GDP     1.2636      0.068     18.668      0.000       1.131       1.396
# ma.L2.D.GDP     0.9995      0.086     11.615      0.000       0.831       1.168
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.8074           -0.9233j            1.2266           -0.3644
# AR.2           -0.8074           +0.9233j            1.2266            0.3644
# MA.1           -0.6321           -0.7752j            1.0002           -0.3589
# MA.2           -0.6321           +0.7752j            1.0002            0.3589
# -----------------------------------------------------------------------------

# %%
model_fit.plot_predict()
plt.savefig('./GDP_diff1_pred.png')

# %%
forecast = model_fit.forecast(steps=10)
pred_y = forecast[0].tolist()

plt.plot(pred_y)
plt.savefig('./GDP_10y_prd.png')

# %%
pred_y
# Out:
# [416597439032.4396,
#  421992454116.21924,
#  410843635858.5455,
#  436154543908.3366,
#  433326110134.73065,
#  436467862048.20807,
#  451905331273.6019,
#  450176178316.73834,
#  458700802718.3613,
#  467629592535.99347]

# %% [markdown]
# 결론: 아르헨티나 GDP는 2021, 2022년에는 전년 대비 상승, 2023년에는 소폭 하락할 것이나, 이후 지속적인 상승세를 보일 것이다

# %% [markdown]
# - 2021년 하반기 GDP 예측: 425,000,000,000 USD
# - 2022년 GDP 예측: 437,000,000,000 USD
# - 2023년 GDP 예측: 443,000,000,000 USD
#
# - ARIMA에서의 2021 GDP 예측: 416597439032.4396 USD
# - ARIMA에서의 2022 GDP 예측: 421992454116.21924 USD
# - ARIMA에서의 2023 GDP 예측: 410843635858.5455 USD

# %% [markdown]
# 비교: Trading Economics에서는 아르헨티나 GDP의 하락 없는 지속적 상승을 예측하였으나, ARIMA는 2023년 후 소폭 하락 이후 상승을 예측하였다. ARIMA의 경우 2017~2020 사이 지속적 GDP 하락 모형을 보여주어 이후 몇년간 GDP하락을 예측하였으나, 전체적 모형의 상승세에 따라 장기적으로는 GDP가 상승할 것으로 예측한 것으로 보인다.

# %%
416597439032.4396 / 383067000000
# Out:
# 1.0875315259013165

# %% [markdown]
# ARIMA는 2021년의 GDP증가율은 약 8.8%라고 예측하였다. 이는 Argentina Central Bank에서의 조사에서 발표한 7.2% 증가와 유사한 수치를 보인다.
